# %%
#importing tools to do statistics and data manipulation
import numpy as np
import pandas as pd

# %%
#Reads in ACLED DATASET
data = pd.read_excel('USA_2020_Oct03update.xlsx')

# %%
data.head()
# Out:
#    ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY EVENT_DATE  YEAR  TIME_PRECISION  \
# 0  840       USA4524              4524 2020-05-24  2020               1
# 1  840       USA4525              4525 2020-05-24  2020               1
# 2  840       USA4526              4526 2020-05-24  2020               1
# 3  840       USA4527              4527 2020-05-24  2020               1
# 4  840       USA4528              4528 2020-05-24  2020               1
#
#   EVENT_TYPE    SUB_EVENT_TYPE                      ACTOR1  \
# 0   Protests  Peaceful protest  Protesters (United States)
# 1   Protests  Peaceful protest  Protesters (United States)
# 2   Protests  Peaceful protest  Protesters (United States)
# 3   Protests  Peaceful protest  Protesters (United States)
# 4   Protests  Peaceful protest  Protesters (United States)
#
#                                        ASSOC_ACTOR_1  ...          ADMIN2  \
# 0                                                NaN  ...  Baltimore City
# ...

# %%
data.describe()
# Out:
#            ISO  EVENT_ID_NO_CNTY     YEAR  TIME_PRECISION        INTER1  \
# count  14012.0      14012.000000  14012.0    14012.000000  14012.000000
# mean     840.0       7077.432201   2020.0        1.008635      5.854767
# std        0.0       4092.840440      0.0        0.092528      0.662604
# min      840.0          1.000000   2020.0        1.000000      1.000000
# 25%      840.0       3512.750000   2020.0        1.000000      6.000000
# 50%      840.0       7095.500000   2020.0        1.000000      6.000000
# 75%      840.0      10630.250000   2020.0        1.000000      6.000000
# max      840.0      14138.000000   2020.0        2.000000      7.000000
#
#              INTER2   INTERACTION  ADMIN3      LATITUDE     LONGITUDE  \
# count  14012.000000  14012.000000     0.0  14012.000000  14012.000000
# mean       0.384599     55.924351     NaN     38.499635    -92.287411
# std        1.336113     12.937643     NaN      5.180939     17.488520
# ...

# %%
# Questions to explore
# 1. How many demonstrations resulted in 2 deaths?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14012 entries, 0 to 14011
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ISO               14012 non-null  int64
#  1   EVENT_ID_CNTY     14012 non-null  object
#  2   EVENT_ID_NO_CNTY  14012 non-null  int64
#  3   EVENT_DATE        14012 non-null  datetime64[ns]
#  4   YEAR              14012 non-null  int64
#  5   TIME_PRECISION    14012 non-null  int64
#  6   EVENT_TYPE        14012 non-null  object
#  7   SUB_EVENT_TYPE    14012 non-null  object
#  8   ACTOR1            14012 non-null  object
#  9   ASSOC_ACTOR_1     11343 non-null  object
#  10  INTER1            14012 non-null  int64
#  11  ACTOR2            1760 non-null   object
#  12  ASSOC_ACTOR_2     437 non-null    object
#  13  INTER2            14012 non-null  int64
#  14  INTERACTION       14012 non-null  int64
#  15  REGION            14012 non-null  object
# ...

# %%
# Getting all rows where there were 2 fatalities
demonstrate_2_fatal=data.loc[data['FATALITIES'] == 2]

# %%
# First look at what is left when filtering for 2 deaths
demonstrate_2_fatal.head()
# Out:
#        ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY EVENT_DATE  YEAR  TIME_PRECISION  \
# 1507   840       USA5990              5990 2020-06-01  2020               1
# 8887   840       USA2778              2778 2020-07-19  2020               1
# 11417  840      USA11280             11280 2020-08-25  2020               1
#
#                        EVENT_TYPE         SUB_EVENT_TYPE  \
# 1507                        Riots  Violent demonstration
# 8887   Violence against civilians                 Attack
# 11417                       Riots  Violent demonstration
#
#                                  ACTOR1            ASSOC_ACTOR_1  ...  \
# 1507            Rioters (United States)  BLM: Black Lives Matter  ...
# 8887   Sole Perpetrator (United States)                      NaN  ...
# 11417           Rioters (United States)  BLM: Black Lives Matter  ...
#
#           ADMIN2 ADMIN3         LOCATION  LATITUDE  LONGITUDE GEO_PRECISION  \
# ...

# %%
# Looking at the Notes columns to see the details surround the event
demonstrate_2_fatal.NOTES

# %% [markdown]
# ## Looking at the notes of each event individually

# %%
demonstrate_2_fatal.NOTES[1507]
# Out:
# 'On 1 June 2020, people demonstrated and rioted, vandalizing and looting stores, in Cicero (Illinois) in support of the Black Lives Matter movement and against police brutality. Police intervened and 60 people were arrested. Two bystanders were shot dead during the riot. [size=at least 60]'

# %%
demonstrate_2_fatal.NOTES[8887]
# Out:
# 'On 19 July 2020, a man shot at family members of a US District Judge, Esther Salas, close to New Brunswick in the North Brunswick Township (New Jersey). The son died, while the husband was injured seriously. The man posed as a Fedex delivery man. Salas was nominated by former President Obama and confirmed. She was the first Latina magistrate in New Jersey. The suspect was a self-described anti-feminist and was later found dead from a self-inflicted gun wound.'

# %%
demonstrate_2_fatal.NOTES[11417]
# Out:
# 'On 25 August 2020, about 1,000 demonstrators gathered outside the courthouse in Kenosha (Wisconsin) in support of the Black Lives Matter movement and against police brutality and the deaths of both George Floyd and Jacob Blake. Demonstrators set off fireworks aimed at officers, while police shot tear gas pellets and rubber bullets into the crowd. A teenager shot and killed two demonstrators and injured another car dealership. The teenager was responding to a Kenosha Guard call-to-action called the "Armed Citizens to Protect our Lives and Property" and joined a security detail including the Kenosha Guard and local Boogaloo Bois, but reportedly was not a member of the two groups. Police reportedly welcomed the suspect and other armed individuals present at the demonstration prior to the shooting. The teenager was not detained at the scene, but was later arrested and has since been charged with homicide. [size=about 1000]'

# %%
# Getting all rows where there was 1 fatality
demonstrate_1_fatal=data.loc[data['FATALITIES'] == 1]

# %%
demonstrate_1_fatal.describe()
# Out:
#          ISO  EVENT_ID_NO_CNTY    YEAR  TIME_PRECISION     INTER1     INTER2  \
# count   48.0         48.000000    48.0            48.0  48.000000  48.000000
# mean   840.0       8296.854167  2020.0             1.0   2.583333   5.125000
# std      0.0       4354.861265     0.0             0.0   1.976816   2.523296
# min    840.0        376.000000  2020.0             1.0   1.000000   1.000000
# 25%    840.0       4668.750000  2020.0             1.0   1.000000   3.000000
# 50%    840.0      10438.500000  2020.0             1.0   1.000000   7.000000
# 75%    840.0      11692.000000  2020.0             1.0   5.000000   7.000000
# max    840.0      14135.000000  2020.0             1.0   6.000000   7.000000
#
#        INTERACTION  ADMIN3   LATITUDE   LONGITUDE  GEO_PRECISION  FATALITIES
# count    48.000000     0.0  48.000000   48.000000           48.0        48.0
# mean     21.958333     NaN  37.654812 -101.234708            1.0         1.0
# ...

# %%
demonstrate_1_fatal.NOTES
# Out:
# 6        On 25 May 2020, four Minneapolis police office...
# 15       Other: On 25 May 2020, an Arizona Department o...
# 32       On 27 May 2020, a Black Lives Matter demonstra...
# 55       On 28 May 2020, thousands of people demonstrat...
# 176      On 29 May 2020, during a demonstration in Oakl...
# 332      On 30 May 2020, over 2,000 people demonstrated...
# 340      On 30 May 2020, up to 1,000 people gathered as...
# 834      On 31 May 2020, during a Black Lives Matter de...
# 1397     On 1 June 2020, demonstrators supporting the B...
# 1449     On 1 June 2020, demonstrators threw rocks at p...
# 1820     Other: On 1 June 2020, a black barbecue owner,...
# 1927     On 2 June 2020, hundreds of people staged a ma...
# 2330     On 2 June 2020, in Vallejo (California), a pol...
# 2799     On 3 June 2020, about 100 people demonstrated ...
# 4279     On 6 June 2020, an armed clash ensued between ...
# 5427     On 12 June 2020, an Atlanta police officer sho...
# ...

# %%
demonstrate_1_fatal.NOTES[6]
# Out:
# 'On 25 May 2020, four Minneapolis police officers arrested a Black man, George Floyd, in Minneapolis (Minnesota) for allegedly using a counterfeit 20 dollar bill at a store. One white police officer knelt on Floyd\'s neck for a total of 8 minutes and 46 seconds, leading to his death. Prior to this, the four officers handcuffed Floyd and held him in a facedown position. Three of the officers applied pressure to his neck, torso, and back. Floyd repeatedly said "I can\'t breathe" before falling unconscious. Floyd was taken away by EMTs and later pronounced dead. All four officers were fired. The officer who used his knee to pin Floyd down was charged with second-degree murder. The other three officers were charged with aiding and abetting the murder. This event has galvanized support for the Black Lives Matter movement and triggered demonstrations worldwide.'

# %%
demonstrate_1_fatal.NOTES[12741]
# Out:
# 'Other: On 13 September 2020, a police officer fatally shot Ricardo Munoz, a Latino man with mental illness, in Lancaster (Pennsylvania) after responding to a domestic disturbance call, where the man chased the officer down the street with a knife. This event prompted multiple protests.'

# %%
# I will use this random fatality to look further into the specific incident and the demonstrations that took place as a result
demonstrate_1_fatal.NOTES[10961]
# Out:
# 'Other: On 21 August 2020, police tased a Black man while responding to a disturbance call involving a person armed with a knife, in Lafayette (Louisiana). The police officers continued to pursue him after he was tasered, surrounding him at the entrance of a Shell station and killing him after firing 11 rounds. The incident has sparked demonstrations, with activists calling it "inappropriate and excessive use of force" by the police.'

# %% [markdown]
# Here is the link to the an article describing the event in more full detail:
# https://www.theadvocate.com/acadiana/news/crime_police/article_93043d66-e48a-11ea-b7c6-77838e38234d.html

# %% [markdown]
# .
# ### NFAC protest in Lafayette over the police shooting of Trayford Pellerin ends peacefully
#
# ###### By Kelly Murray, Angela Barajas and Ryan Young, CNN
# https://www.cnn.com/2020/10/04/us/louisiana-gun-discharge-demonstration-trayford-pellerin-death/index.html
